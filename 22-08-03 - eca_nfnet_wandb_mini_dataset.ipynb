# %% [markdown]
# # Reproduction of kaggle first place

# %% [markdown]
# Based on:
#
# https://www.kaggle.com/c/seti-breakthrough-listen/discussion/266385
#
# https://www.kaggle.com/code/ligtfeather/eca-nfnet-sam-opt-mixup-k-folds-w-b

# %% [markdown]
# First place solution architecture:
#
# ![image.png](attachment:85f23176-7ede-4cd8-9559-f74e129a1e88.png)

# %%
# !pip install timm
# !pip install albumentations
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113

# %%
import os
import random
from tqdm import tqdm
from collections import defaultdict
from datetime import datetime

import torch
import torch.nn as nn
from torch.optim import Adam, SGD
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torch.optim.lr_scheduler import CosineAnnealingLR

import torchvision.transforms as transforms
import cv2

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

import numpy as np
import pandas as pd
import timm
from adamp import AdamP

import albumentations
from albumentations.pytorch.transforms import ToTensorV2

import wandb
from matplotlib import pyplot as plt

# %%
config = {
    'num_workers': 4,
    'model': 'eca_nfnet_l0',
    'device': 'cuda',
    'image_size': 224,
    'input_channels': 1,
    'output_features': 1,
    'seed': 42,
    'target_size': 1,
    'T_max': 10,
    'min_lr': 1e-6,
    'lr': 1e-4,
    'weight_decay': 1e-6,
    'batch_size': 32,
    'epochs': 50,
    'num_folds': 10
}

# %%
def set_seeds(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

set_seeds(seed=config['seed'])

# %% [markdown]
# # Data Loading

# %%
train_data_dir = r'D:\UoL\Level 6\CM3070 - Final Project\SETI Signal Detection\Data\train'
labels_filepath = os.path.join(train_data_dir, '2000_balanced_labels.npy')

with open(labels_filepath, 'rb') as f:
    initial_data = np.load(f, allow_pickle=True)
    
initial_data_df = pd.DataFrame(initial_data, columns=['id', 'target', 'image_filepath']).convert_dtypes()
initial_data_df['target'] = initial_data_df['target'].astype('int')

# %%
initial_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2000 non-null   string
#  1   target          2000 non-null   int32
#  2   image_filepath  2000 non-null   string
# dtypes: int32(1), string(2)
# memory usage: 39.2 KB

# %% [markdown]
# Split the data into 70% train and 30% test:

# %%
data_split_mask = np.random.rand(len(initial_data_df)) < 0.7

train_df = initial_data_df[data_split_mask]
test_df = initial_data_df[~data_split_mask]

# %% [markdown]
# # Custom Dataset

# %%
def resize_image(image):
    # img = cv2.imread('your_image.jpg')
    return cv2.resize(image, dsize=(config['image_size'], config['image_size']), interpolation=cv2.INTER_CUBIC)

def plot_image(image):
    plt.figure(figsize = (20, 6))
    plt.imshow(image, aspect='auto')
    plt.show()

# %%
class CustomDataset(Dataset):
    def __init__(self, images_filepaths, targets, transform=None):
        self.images_filepaths = images_filepaths
        self.targets = targets
        self.transform = transform
        # self.transform = None

    def __len__(self):
        return len(self.images_filepaths)

    def __getitem__(self, idx):
        image_filepath = self.images_filepaths[idx]
        image = np.load(image_filepath).astype(np.float32)
        image = np.vstack(image).transpose((1, 0))
            
        if self.transform is not None:
            image = self.transform(image=image)['image']
        else:
            image = resize_image(image)
            image = image[np.newaxis,:,:]
            image = torch.from_numpy(image).float()
        
        label = torch.tensor(self.targets[idx]).float()

        return image, label

# %% [markdown]
# # Image Augmentation

# %%
def get_train_transforms():
    return albumentations.Compose(
        [
            albumentations.Resize(config['image_size'], config['image_size']),
            albumentations.HorizontalFlip(p=0.5),
            albumentations.VerticalFlip(p=0.5),
            albumentations.Rotate(limit=180, p=0.7),
            albumentations.RandomBrightnessContrast(brightness_limit=0.6, p=0.5),
            albumentations.CoarseDropout(max_holes=10, max_height=12, max_width=12, fill_value=0),
            albumentations.ShiftScaleRotate(shift_limit=0.25, scale_limit=0.1, rotate_limit=0),
            ToTensorV2(p=1.0),
        ]
    )

def get_valid_transforms():
    return albumentations.Compose(
        [
            albumentations.Resize(config['image_size'],config['image_size']),
            ToTensorV2(p=1.0)
        ]
    )

def get_test_transforms():
        return albumentations.Compose(
            [
                albumentations.Resize(config['image_size'], config['image_size']),
                ToTensorV2(p=1.0)
            ]
        )

# %% [markdown]
# ## Mixup

# %%
def mixup(x, y, alpha=1.0, use_cuda=True):

    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %% [markdown]
# # Loss and ROC Monitoring

# %%
class MetricMonitor:
    def __init__(self, float_precision=3):
        self.float_precision = float_precision
        self.reset()

    def reset(self):
        self.metrics = defaultdict(lambda: {"val": 0, "count": 0, "avg": 0})

    def update(self, metric_name, val):
        metric = self.metrics[metric_name]

        metric["val"] += val
        metric["count"] += 1
        metric["avg"] = metric["val"] / metric["count"]

    def __str__(self):
        return " | ".join(
            [
                "{metric_name}: {avg:.{float_precision}f}".format(
                    metric_name=metric_name, avg=metric["avg"],
                    float_precision=self.float_precision
                )
                for (metric_name, metric) in self.metrics.items()
            ]
        )
    
def use_roc_score(output, target):
    try:
        y_pred = torch.sigmoid(output).cpu()
        y_pred = y_pred.detach().numpy()
        target = target.cpu()

        return roc_auc_score(target, y_pred)
    except:
        return 0.5

# %% [markdown]
# # Weight Random Sampler

# %%
def get_sampler(train_data):
    class_counts = train_data['target'].value_counts().to_list()
    num_samples = sum(class_counts)
    labels = train_data['target'].to_list()

    class_weights = [num_samples/class_counts[i] for i in range(len(class_counts))]
    weights = [class_weights[labels[i]] for i in range(int(num_samples))]

    return WeightedRandomSampler(torch.DoubleTensor(weights), int(num_samples))

# %% [markdown]
# # Train and Validation Dataloaders

# %%
def get_loaders(train_data, valid_data, sampler):
    training_set = CustomDataset(
        images_filepaths=train_data['image_filepath'].values,
        targets=train_data['target'].values,
        transform=get_train_transforms()
    )

    validation_set = CustomDataset(
        images_filepaths=valid_data['image_filepath'].values,
        targets=valid_data['target'].values,
        transform=get_valid_transforms()
    )

    train_loader = DataLoader(
        training_set,
        batch_size=config['batch_size'],
        # shuffle=True,
        # num_workers=config['num_workers'],
        sampler = sampler,
        pin_memory=True
    )

    valid_loader = DataLoader(
        validation_set,
        batch_size=config['batch_size'],
        shuffle=False,
        # num_workers=config['num_workers'],
        pin_memory=True
    )

    return train_loader, valid_loader

# %% [markdown]
# # Model

# %%
class EcaNFNet(nn.Module):
    def __init__(self, model_name=config['model'], output_features=config['output_features'],
                 input_channels=config['input_channels'], pretrained=True):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained,
                                       in_chans=input_channels)
        n_features = self.model.head.fc.in_features
        self.model.head.fc = nn.Linear(n_features, output_features, bias=True)    
    
    def forward(self, x):
        x = self.model(x)
        return x

# %% [markdown]
# # Sharpness Aware Minimisation (SAM) Optimiser

# %%
class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"

        defaults = dict(rho=rho, **kwargs)
        super(SAM, self).__init__(params, defaults)

        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()

        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)

            for p in group["params"]:
                if p.grad is None: continue
                e_w = p.grad * scale.to(p)
                p.add_(e_w)  # climb to the local maximum "w + e(w)"
                self.state[p]["e_w"] = e_w

        self.base_optimizer.step()  # do the actual "sharpness-aware" update

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None: continue
                p.sub_(self.state[p]["e_w"])  # get back to "w" from "w + e(w)"

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def step(self, closure=None):
        assert closure is not None, "Sharpness Aware Minimization requires closure, but it was not provided"
        closure = torch.enable_grad()(closure)  # the closure should do a full forward-backward pass

        self.first_step(zero_grad=True)
        closure()
        self.second_step()

    def _grad_norm(self):
        shared_device = self.param_groups[0]["params"][0].device  # put everything on the same device, in case of model parallelism
        norm = torch.norm(
                    torch.stack([
                        p.grad.norm(p=2).to(shared_device)
                        for group in self.param_groups for p in group["params"]
                        if p.grad is not None
                    ]),
                    p=2
               )
        return norm

# %% [markdown]
# # Initialise Model, Loss Function, Optimizer and Scheduler

# %%
model = EcaNFNet()
model = model.to(config['device'])
criterion = nn.BCEWithLogitsLoss().to(config['device'])
base_optimizer = AdamP
optimizer = SAM(model.parameters(), base_optimizer, lr=config['lr'], weight_decay=config['weight_decay'])

scheduler = CosineAnnealingLR(optimizer,
                              T_max=config['T_max'],
                              eta_min=config['min_lr'],
                              last_epoch=-1)

# %% [markdown]
# # K-Fold CV

# %%
def train(train_loader, model, criterion, optimizer, epoch, scheduler):
    metric_monitor = MetricMonitor()
    model.train()
    stream = tqdm(enumerate(train_loader), total=len(train_loader))
       
    for i, (images, target, images_indices) in stream:
        images = images.to(config['device'])
        target = target.to(config['device']).float().view(-1, 1)
        images, targets_a, targets_b, lam = mixup(images, target.view(-1, 1))

        optimizer.zero_grad()

        output = model(images)

        loss = mixup_criterion(criterion, output, targets_a, targets_b, lam)
        loss.backward(retain_graph = True)

        optimizer.first_step(zero_grad=False)
        
        mixup_criterion(criterion, model(images), targets_a, targets_b, lam).backward()
        optimizer.second_step(zero_grad=False)
        
        roc_score = use_roc_score(output, target)

        metric_monitor.update('Loss', loss.item())
        metric_monitor.update('ROC', roc_score)

        wandb.log({'Train Epoch': epoch, 'Train loss': loss.item(), 'Train ROC': roc_score})

        stream.set_description('Epoch: {epoch}. Train. {metric_monitor}'
                               .format(epoch=epoch, metric_monitor=metric_monitor))

    scheduler.step()

# %%
def validate(val_loader, model, criterion, epoch):
    metric_monitor = MetricMonitor()
    model.eval()
    stream = tqdm(enumerate(val_loader), total=len(val_loader))
    final_targets = []
    final_outputs = []

    with torch.no_grad():
        for i, (images, target, image_indices) in stream:
            images = images.to(config['device'], non_blocking=True)
            target = target.to(config['device'], non_blocking=True).float().view(-1, 1)

            output = model(images)
            loss = criterion(output, target)
            roc_score = use_roc_score(output, target)

            metric_monitor.update('Loss', loss.item())
            metric_monitor.update('ROC', roc_score)

            wandb.log({"Valid Epoch": epoch, "Valid loss": loss.item(), "Valid ROC":roc_score})

            stream.set_description("Epoch: {epoch}. Validation. {metric_monitor}"
                                   .format(epoch=epoch, metric_monitor=metric_monitor))
            
            targets = target.detach().cpu().numpy().tolist()
            outputs = output.detach().cpu().numpy().tolist()
            
            final_targets.extend(targets)
            final_outputs.extend(outputs)

    return final_outputs, final_targets

# %% [markdown]
# # W&B Initialisation for K-Fold CV

# %% [markdown]
# **W&B API key**: 47b00b0f6291346fe94ab4a6dceca03a809fbf4a

# %% [markdown]
# # Training loop

# %% [markdown]
# Create directory to save models for this run:

# %%
current_datetime = datetime.now().strftime("%y-%m-%d_%H-%M-%S")
models_dir = os.path.join('models', current_datetime)
os.mkdir(models_dir)

# %% [markdown]
# Execute the training loop:

# %%
best_roc = -np.inf
best_epoch = -np.inf
best_model_name = None
kfold = StratifiedKFold(n_splits=config['num_folds'], shuffle=True, random_state=config['seed'])

for fold, (trn_idx, val_idx) in enumerate(kfold.split(train_df, train_df['target'])):
    run = wandb.init(
            project='eca-NFNet-Mixup',
            config=config,
            group='ECA-NFNet',
            job_type='train',
            name=f"{current_datetime} - fold {fold}")

    print(f"{'='*40} Fold: {fold} {'='*40}")

    train_data = train_df.iloc[trn_idx]
    valid_data = train_df.iloc[val_idx]

    sampler = get_sampler(train_data)

    train_loader, valid_loader = get_loaders(train_data, valid_data, sampler)

    for epoch in range(1, config['epochs'] + 1):
        train(train_loader, model, criterion, optimizer, epoch, scheduler)
        valid_predictions, valid_targets = validate(valid_loader, model, criterion, epoch)

        valid_roc_auc = round(roc_auc_score(valid_targets, valid_predictions), 3)

        torch.save(model.state_dict(), os.path.join(models_dir, f"{config['model']}_{epoch}_epoch_{valid_roc_auc}_roc_auc.pth"))

        if valid_roc_auc > best_roc:
            best_roc = valid_roc_auc
            best_epoch = epoch
            best_model_name = f"{config['model']}_{epoch}_epoch_{valid_roc_auc}_roc_auc.pth"

    print(f'Best ROC-AUC in fold {fold} was {best_roc:.4f}')
    print(f'Final ROC-AUC in fold {fold} was {valid_roc_auc:.4f}')
    print(f'Best model name in fold {fold} was {best_model_name}')
# Out:
# wandb: Currently logged in as: mllm. Use `wandb login --relogin` to force relogin
# wandb version 0.13.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>D:\UoL\Level 6\CM3070 - Final Project\SETI Signal Detection\Prototype\wandb\run-20220803_222105-3e2308uj</code>
# Syncing run <strong><a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/3e2308uj" target="_blank">22-08-03 22_21_04 - fold 0</a></strong> to <a href="https://wandb.ai/mllm/eca-NFNet-Mixup" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ======================================== Fold: 0 ========================================
# Epoch: 1. Train. Loss: 0.698 | ROC: 0.512: 100%|██████████| 40/40 [00:54<00:00,  1.36s/it]
# D:\UoL\Level 6\CM3070 - Final Project\SETI Signal Detection\Prototype\venv\lib\site-packages\torch\optim\lr_scheduler.py:131: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch: 1. Validation. Loss: 0.688 | ROC: 0.494: 100%|██████████| 5/5 [00:01<00:00,  3.61it/s]
# Epoch: 2. Train. Loss: 0.692 | ROC: 0.521: 100%|██████████| 40/40 [00:50<00:00,  1.26s/it]
# Epoch: 2. Validation. Loss: 0.697 | ROC: 0.481: 100%|██████████| 5/5 [00:01<00:00,  3.27it/s]
# Epoch: 3. Train. Loss: 0.694 | ROC: 0.550: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 3. Validation. Loss: 0.687 | ROC: 0.507: 100%|██████████| 5/5 [00:01<00:00,  3.53it/s]
# Epoch: 4. Train. Loss: 0.695 | ROC: 0.500: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 4. Validation. Loss: 0.692 | ROC: 0.537: 100%|██████████| 5/5 [00:01<00:00,  3.38it/s]
# Epoch: 5. Train. Loss: 0.693 | ROC: 0.482: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 5. Validation. Loss: 0.691 | ROC: 0.533: 100%|██████████| 5/5 [00:01<00:00,  3.59it/s]
# Epoch: 6. Train. Loss: 0.692 | ROC: 0.507: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it]
# Epoch: 6. Validation. Loss: 0.693 | ROC: 0.476: 100%|██████████| 5/5 [00:01<00:00,  3.59it/s]
# Epoch: 7. Train. Loss: 0.691 | ROC: 0.541: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 7. Validation. Loss: 0.702 | ROC: 0.477: 100%|██████████| 5/5 [00:01<00:00,  3.62it/s]
# Epoch: 8. Train. Loss: 0.692 | ROC: 0.522: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it]
# Epoch: 8. Validation. Loss: 0.687 | ROC: 0.502: 100%|██████████| 5/5 [00:01<00:00,  3.53it/s]
# Epoch: 9. Train. Loss: 0.691 | ROC: 0.541: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it]
# Epoch: 9. Validation. Loss: 0.687 | ROC: 0.498: 100%|██████████| 5/5 [00:01<00:00,  3.63it/s]
# Epoch: 10. Train. Loss: 0.690 | ROC: 0.529: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 10. Validation. Loss: 0.687 | ROC: 0.497: 100%|██████████| 5/5 [00:01<00:00,  3.52it/s]
# Epoch: 11. Train. Loss: 0.693 | ROC: 0.510: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 11. Validation. Loss: 0.687 | ROC: 0.498: 100%|██████████| 5/5 [00:01<00:00,  3.59it/s]
# Epoch: 12. Train. Loss: 0.692 | ROC: 0.502: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 12. Validation. Loss: 0.687 | ROC: 0.497: 100%|██████████| 5/5 [00:01<00:00,  3.64it/s]
# Epoch: 13. Train. Loss: 0.692 | ROC: 0.524: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it]
# Epoch: 13. Validation. Loss: 0.692 | ROC: 0.487: 100%|██████████| 5/5 [00:01<00:00,  3.63it/s]
# Epoch: 14. Train. Loss: 0.691 | ROC: 0.507: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 14. Validation. Loss: 0.695 | ROC: 0.494: 100%|██████████| 5/5 [00:01<00:00,  3.51it/s]
# Epoch: 15. Train. Loss: 0.691 | ROC: 0.520: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it]
# Epoch: 15. Validation. Loss: 0.695 | ROC: 0.496: 100%|██████████| 5/5 [00:01<00:00,  3.29it/s]
# Epoch: 16. Train. Loss: 0.693 | ROC: 0.509: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 16. Validation. Loss: 0.693 | ROC: 0.478: 100%|██████████| 5/5 [00:01<00:00,  3.60it/s]
# Epoch: 17. Train. Loss: 0.694 | ROC: 0.503: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 17. Validation. Loss: 0.691 | ROC: 0.500: 100%|██████████| 5/5 [00:01<00:00,  3.57it/s]
# Epoch: 18. Train. Loss: 0.692 | ROC: 0.517: 100%|██████████| 40/40 [00:52<00:00,  1.31s/it]
# Epoch: 18. Validation. Loss: 0.690 | ROC: 0.509: 100%|██████████| 5/5 [00:01<00:00,  3.64it/s]
# Epoch: 19. Train. Loss: 0.695 | ROC: 0.509: 100%|██████████| 40/40 [00:53<00:00,  1.33s/it]
# Epoch: 19. Validation. Loss: 0.690 | ROC: 0.473: 100%|██████████| 5/5 [00:01<00:00,  3.57it/s]
# Epoch: 20. Train. Loss: 0.689 | ROC: 0.549: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 20. Validation. Loss: 0.692 | ROC: 0.482: 100%|██████████| 5/5 [00:01<00:00,  3.51it/s]
# Epoch: 21. Train. Loss: 0.694 | ROC: 0.514: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 21. Validation. Loss: 0.692 | ROC: 0.507: 100%|██████████| 5/5 [00:01<00:00,  3.39it/s]
# Epoch: 22. Train. Loss: 0.693 | ROC: 0.510: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 22. Validation. Loss: 0.696 | ROC: 0.510: 100%|██████████| 5/5 [00:01<00:00,  3.37it/s]
# Epoch: 23. Train. Loss: 0.693 | ROC: 0.516: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it]
# Epoch: 23. Validation. Loss: 0.716 | ROC: 0.491: 100%|██████████| 5/5 [00:01<00:00,  3.37it/s]
# Epoch: 24. Train. Loss: 0.691 | ROC: 0.530: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it]
# Epoch: 24. Validation. Loss: 0.692 | ROC: 0.515: 100%|██████████| 5/5 [00:01<00:00,  3.31it/s]
# Epoch: 25. Train. Loss: 0.693 | ROC: 0.509: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 25. Validation. Loss: 0.691 | ROC: 0.506: 100%|██████████| 5/5 [00:01<00:00,  3.50it/s]
# Epoch: 26. Train. Loss: 0.692 | ROC: 0.518: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 26. Validation. Loss: 0.687 | ROC: 0.515: 100%|██████████| 5/5 [00:01<00:00,  3.37it/s]
# Epoch: 27. Train. Loss: 0.691 | ROC: 0.509: 100%|██████████| 40/40 [00:51<00:00,  1.30s/it]
# Epoch: 27. Validation. Loss: 0.681 | ROC: 0.504: 100%|██████████| 5/5 [00:01<00:00,  3.25it/s]
# Epoch: 28. Train. Loss: 0.694 | ROC: 0.501: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it]
# Epoch: 28. Validation. Loss: 0.684 | ROC: 0.498: 100%|██████████| 5/5 [00:01<00:00,  3.33it/s]
# Epoch: 29. Train. Loss: 0.691 | ROC: 0.524: 100%|██████████| 40/40 [00:51<00:00,  1.30s/it]
# Epoch: 29. Validation. Loss: 0.686 | ROC: 0.508: 100%|██████████| 5/5 [00:01<00:00,  3.46it/s]
# Epoch: 30. Train. Loss: 0.691 | ROC: 0.543: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 30. Validation. Loss: 0.685 | ROC: 0.507: 100%|██████████| 5/5 [00:01<00:00,  3.50it/s]
# Epoch: 31. Train. Loss: 0.691 | ROC: 0.517: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 31. Validation. Loss: 0.684 | ROC: 0.506: 100%|██████████| 5/5 [00:01<00:00,  3.52it/s]
# Epoch: 32. Train. Loss: 0.689 | ROC: 0.539: 100%|██████████| 40/40 [00:51<00:00,  1.30s/it]
# Epoch: 32. Validation. Loss: 0.683 | ROC: 0.515: 100%|██████████| 5/5 [00:01<00:00,  3.46it/s]
# Epoch: 33. Train. Loss: 0.689 | ROC: 0.535: 100%|██████████| 40/40 [00:51<00:00,  1.30s/it]
# Epoch: 33. Validation. Loss: 0.678 | ROC: 0.523: 100%|██████████| 5/5 [00:01<00:00,  3.47it/s]
# Epoch: 34. Train. Loss: 0.690 | ROC: 0.533: 100%|██████████| 40/40 [00:52<00:00,  1.31s/it]
# Epoch: 34. Validation. Loss: 0.678 | ROC: 0.520: 100%|██████████| 5/5 [00:01<00:00,  3.34it/s]
# Epoch: 35. Train. Loss: 0.690 | ROC: 0.564: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it]
# Epoch: 35. Validation. Loss: 0.678 | ROC: 0.502: 100%|██████████| 5/5 [00:01<00:00,  3.45it/s]
# Epoch: 36. Train. Loss: 0.692 | ROC: 0.515: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 36. Validation. Loss: 0.681 | ROC: 0.503: 100%|██████████| 5/5 [00:01<00:00,  3.63it/s]
# Epoch: 37. Train. Loss: 0.690 | ROC: 0.529: 100%|██████████| 40/40 [00:52<00:00,  1.30s/it]
# Epoch: 37. Validation. Loss: 0.680 | ROC: 0.503: 100%|██████████| 5/5 [00:01<00:00,  3.44it/s]
# Epoch: 38. Train. Loss: 0.693 | ROC: 0.520: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it]
# Epoch: 38. Validation. Loss: 0.669 | ROC: 0.543: 100%|██████████| 5/5 [00:01<00:00,  3.40it/s]
# Epoch: 39. Train. Loss: 0.690 | ROC: 0.517: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 39. Validation. Loss: 0.688 | ROC: 0.542: 100%|██████████| 5/5 [00:01<00:00,  3.40it/s]
# Epoch: 40. Train. Loss: 0.689 | ROC: 0.525: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it]
# Epoch: 40. Validation. Loss: 0.616 | ROC: 0.524: 100%|██████████| 5/5 [00:01<00:00,  3.51it/s]
# Epoch: 41. Train. Loss: 0.689 | ROC: 0.549: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 41. Validation. Loss: 0.706 | ROC: 0.530: 100%|██████████| 5/5 [00:01<00:00,  3.43it/s]
# Epoch: 42. Train. Loss: 0.689 | ROC: 0.519: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 42. Validation. Loss: 0.706 | ROC: 0.520: 100%|██████████| 5/5 [00:01<00:00,  3.56it/s]
# Epoch: 43. Train. Loss: 0.692 | ROC: 0.518: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it]
# Epoch: 43. Validation. Loss: 0.690 | ROC: 0.536: 100%|██████████| 5/5 [00:01<00:00,  3.36it/s]
# Epoch: 44. Train. Loss: 0.689 | ROC: 0.545: 100%|██████████| 40/40 [00:52<00:00,  1.31s/it]
# Epoch: 44. Validation. Loss: 0.686 | ROC: 0.511: 100%|██████████| 5/5 [00:01<00:00,  3.47it/s]
# Epoch: 45. Train. Loss: 0.692 | ROC: 0.508: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it]
# Epoch: 45. Validation. Loss: 0.699 | ROC: 0.520: 100%|██████████| 5/5 [00:01<00:00,  3.29it/s]
# Epoch: 46. Train. Loss: 0.689 | ROC: 0.553: 100%|██████████| 40/40 [00:54<00:00,  1.35s/it]
# Epoch: 46. Validation. Loss: 0.690 | ROC: 0.523: 100%|██████████| 5/5 [00:01<00:00,  3.43it/s]
# Epoch: 47. Train. Loss: 0.690 | ROC: 0.538: 100%|██████████| 40/40 [00:52<00:00,  1.31s/it]
# Epoch: 47. Validation. Loss: 0.683 | ROC: 0.515: 100%|██████████| 5/5 [00:01<00:00,  3.40it/s]
# Epoch: 48. Train. Loss: 0.683 | ROC: 0.581: 100%|██████████| 40/40 [00:53<00:00,  1.33s/it]
# Epoch: 48. Validation. Loss: 0.683 | ROC: 0.525: 100%|██████████| 5/5 [00:01<00:00,  3.52it/s]
# Epoch: 49. Train. Loss: 0.685 | ROC: 0.577: 100%|██████████| 40/40 [00:52<00:00,  1.30s/it]
# Epoch: 49. Validation. Loss: 0.682 | ROC: 0.525: 100%|██████████| 5/5 [00:01<00:00,  3.49it/s]
# Epoch: 50. Train. Loss: 0.683 | ROC: 0.559: 100%|██████████| 40/40 [00:52<00:00,  1.30s/it]
# Epoch: 50. Validation. Loss: 0.680 | ROC: 0.525: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Best ROC-AUC in fold 0 was 0.6560
# Final ROC-AUC in fold 0 was 0.5820
# Best model name in fold 0 was eca_nfnet_l0_40_epoch_0.656_roc_auc.pth
# Finishing last run (ID:3e2308uj) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Train ROC</td><td>█▃▄▅▄▃▆▅▃▄▄▃▅▅▅▃▅▂▆▃▆▃▆▇▄▄▆▅▂▆▁▅▇▆▆▄▇▇▃▇</td></tr><tr><td>Train loss</td><td>▂▆▇▅▅▅▄▅▆▅▆▄▃▃▃▆▅▆▆▆▆▆█▅▅▂▅▄▅▅█▄▄▃▄▅▂▂▇▁</td></tr><tr><td>Valid Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Valid ROC</td><td>▄▁▄▄▄▄▄▄▄▄▄▄▁▄▄▄▄▄▄▄▆▄▄▅▄▄▄▄▄▄▄█▄▄▆▄▄▄▄█</td></tr><tr><td>Valid loss</td><td>▅▅▃▃▄▁▂▄▄▄▅▄▄▃▄▂▄▄▄▄▃▂▃▄▃▃▄▄▁▅▄▂█▆▃▆▄▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>50</td></tr><tr><td>Train ROC</td><td>0.45312</td></tr><tr><td>Train loss</td><td>0.70379</td></tr><tr><td>Valid Epoch</td><td>50</td></tr><tr><td>Valid ROC</td><td>0.5</td></tr><tr><td>Valid loss</td><td>0.6169</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">22-08-03 22_21_04 - fold 0</strong>: <a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/3e2308uj" target="_blank">https://wandb.ai/mllm/eca-NFNet-Mixup/runs/3e2308uj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220803_222105-3e2308uj\logs</code>
# Successfully finished last run (ID:3e2308uj). Initializing new run:<br/>
# wandb version 0.13.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>D:\UoL\Level 6\CM3070 - Final Project\SETI Signal Detection\Prototype\wandb\run-20220803_230543-2toedihs</code>
# Syncing run <strong><a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/2toedihs" target="_blank">22-08-03 23_05_43 - fold 1</a></strong> to <a href="https://wandb.ai/mllm/eca-NFNet-Mixup" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ======================================== Fold: 1 ========================================
# Epoch: 1. Train. Loss: 0.685 | ROC: 0.544: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 1. Validation. Loss: 0.647 | ROC: 0.556: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 2. Train. Loss: 0.682 | ROC: 0.543: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 2. Validation. Loss: 0.646 | ROC: 0.561: 100%|██████████| 5/5 [00:01<00:00,  3.98it/s]
# Epoch: 3. Train. Loss: 0.681 | ROC: 0.572: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 3. Validation. Loss: 0.651 | ROC: 0.549: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 4. Train. Loss: 0.686 | ROC: 0.538: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 4. Validation. Loss: 0.647 | ROC: 0.568: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 5. Train. Loss: 0.688 | ROC: 0.528: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 5. Validation. Loss: 0.644 | ROC: 0.552: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 6. Train. Loss: 0.685 | ROC: 0.543: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 6. Validation. Loss: 0.643 | ROC: 0.566: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 7. Train. Loss: 0.679 | ROC: 0.523: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 7. Validation. Loss: 0.653 | ROC: 0.559: 100%|██████████| 5/5 [00:01<00:00,  3.92it/s]
# Epoch: 8. Train. Loss: 0.677 | ROC: 0.554: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 8. Validation. Loss: 0.604 | ROC: 0.565: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 9. Train. Loss: 0.683 | ROC: 0.537: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 9. Validation. Loss: 0.654 | ROC: 0.550: 100%|██████████| 5/5 [00:01<00:00,  3.91it/s]
# Epoch: 10. Train. Loss: 0.684 | ROC: 0.519: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 10. Validation. Loss: 0.640 | ROC: 0.542: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 11. Train. Loss: 0.679 | ROC: 0.570: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 11. Validation. Loss: 0.637 | ROC: 0.568: 100%|██████████| 5/5 [00:01<00:00,  3.97it/s]
# Epoch: 12. Train. Loss: 0.685 | ROC: 0.536: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 12. Validation. Loss: 0.651 | ROC: 0.556: 100%|██████████| 5/5 [00:01<00:00,  3.99it/s]
# Epoch: 13. Train. Loss: 0.683 | ROC: 0.592: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 13. Validation. Loss: 0.666 | ROC: 0.550: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 14. Train. Loss: 0.675 | ROC: 0.571: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 14. Validation. Loss: 0.641 | ROC: 0.556: 100%|██████████| 5/5 [00:01<00:00,  3.98it/s]
# Epoch: 15. Train. Loss: 0.678 | ROC: 0.597: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 15. Validation. Loss: 0.645 | ROC: 0.584: 100%|██████████| 5/5 [00:01<00:00,  3.98it/s]
# Epoch: 16. Train. Loss: 0.680 | ROC: 0.567: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 16. Validation. Loss: 0.631 | ROC: 0.571: 100%|██████████| 5/5 [00:01<00:00,  3.99it/s]
# Epoch: 17. Train. Loss: 0.674 | ROC: 0.576: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 17. Validation. Loss: 0.632 | ROC: 0.581: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 18. Train. Loss: 0.682 | ROC: 0.548: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 18. Validation. Loss: 0.650 | ROC: 0.574: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 19. Train. Loss: 0.673 | ROC: 0.563: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 19. Validation. Loss: 0.652 | ROC: 0.573: 100%|██████████| 5/5 [00:01<00:00,  3.97it/s]
# Epoch: 20. Train. Loss: 0.660 | ROC: 0.615: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 20. Validation. Loss: 0.650 | ROC: 0.571: 100%|██████████| 5/5 [00:01<00:00,  4.01it/s]
# Epoch: 21. Train. Loss: 0.664 | ROC: 0.587: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 21. Validation. Loss: 0.649 | ROC: 0.571: 100%|██████████| 5/5 [00:01<00:00,  4.05it/s]
# Epoch: 22. Train. Loss: 0.665 | ROC: 0.580: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 22. Validation. Loss: 0.643 | ROC: 0.577: 100%|██████████| 5/5 [00:01<00:00,  4.03it/s]
# Epoch: 23. Train. Loss: 0.665 | ROC: 0.558: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 23. Validation. Loss: 0.635 | ROC: 0.578: 100%|██████████| 5/5 [00:01<00:00,  3.97it/s]
# Epoch: 24. Train. Loss: 0.665 | ROC: 0.605: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 24. Validation. Loss: 0.623 | ROC: 0.572: 100%|██████████| 5/5 [00:01<00:00,  3.99it/s]
# Epoch: 25. Train. Loss: 0.670 | ROC: 0.589: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 25. Validation. Loss: 0.629 | ROC: 0.571: 100%|██████████| 5/5 [00:01<00:00,  4.01it/s]
# Epoch: 26. Train. Loss: 0.666 | ROC: 0.609: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 26. Validation. Loss: 0.627 | ROC: 0.573: 100%|██████████| 5/5 [00:01<00:00,  3.97it/s]
# Epoch: 27. Train. Loss: 0.660 | ROC: 0.620: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 27. Validation. Loss: 0.677 | ROC: 0.573: 100%|██████████| 5/5 [00:01<00:00,  4.04it/s]
# Epoch: 28. Train. Loss: 0.667 | ROC: 0.585: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 28. Validation. Loss: 0.736 | ROC: 0.564: 100%|██████████| 5/5 [00:01<00:00,  3.91it/s]
# Epoch: 29. Train. Loss: 0.669 | ROC: 0.597: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 29. Validation. Loss: 0.650 | ROC: 0.562: 100%|██████████| 5/5 [00:01<00:00,  4.03it/s]
# Epoch: 30. Train. Loss: 0.675 | ROC: 0.588: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 30. Validation. Loss: 0.670 | ROC: 0.574: 100%|██████████| 5/5 [00:01<00:00,  3.97it/s]
# Epoch: 31. Train. Loss: 0.674 | ROC: 0.609: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 31. Validation. Loss: 0.662 | ROC: 0.570: 100%|██████████| 5/5 [00:01<00:00,  3.99it/s]
# Epoch: 32. Train. Loss: 0.662 | ROC: 0.587: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 32. Validation. Loss: 0.634 | ROC: 0.564: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 33. Train. Loss: 0.661 | ROC: 0.593: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 33. Validation. Loss: 0.633 | ROC: 0.554: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 34. Train. Loss: 0.668 | ROC: 0.578: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 34. Validation. Loss: 0.656 | ROC: 0.555: 100%|██████████| 5/5 [00:01<00:00,  3.66it/s]
# Epoch: 35. Train. Loss: 0.652 | ROC: 0.617: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 35. Validation. Loss: 0.583 | ROC: 0.579: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 36. Train. Loss: 0.667 | ROC: 0.587: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 36. Validation. Loss: 0.607 | ROC: 0.569: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 37. Train. Loss: 0.652 | ROC: 0.619: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 37. Validation. Loss: 0.617 | ROC: 0.574: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 38. Train. Loss: 0.642 | ROC: 0.607: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 38. Validation. Loss: 0.614 | ROC: 0.576: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 39. Train. Loss: 0.630 | ROC: 0.651: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 39. Validation. Loss: 0.614 | ROC: 0.578: 100%|██████████| 5/5 [00:01<00:00,  3.86it/s]
# Epoch: 40. Train. Loss: 0.645 | ROC: 0.631: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 40. Validation. Loss: 0.611 | ROC: 0.577: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 41. Train. Loss: 0.644 | ROC: 0.597: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 41. Validation. Loss: 0.611 | ROC: 0.577: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 42. Train. Loss: 0.642 | ROC: 0.579: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 42. Validation. Loss: 0.612 | ROC: 0.579: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 43. Train. Loss: 0.635 | ROC: 0.678: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 43. Validation. Loss: 0.609 | ROC: 0.580: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 44. Train. Loss: 0.628 | ROC: 0.627: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 44. Validation. Loss: 0.631 | ROC: 0.578: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 45. Train. Loss: 0.650 | ROC: 0.610: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 45. Validation. Loss: 0.617 | ROC: 0.553: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 46. Train. Loss: 0.641 | ROC: 0.571: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 46. Validation. Loss: 0.665 | ROC: 0.558: 100%|██████████| 5/5 [00:01<00:00,  3.76it/s]
# Epoch: 47. Train. Loss: 0.643 | ROC: 0.598: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 47. Validation. Loss: 0.610 | ROC: 0.565: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 48. Train. Loss: 0.647 | ROC: 0.617: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 48. Validation. Loss: 0.642 | ROC: 0.570: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 49. Train. Loss: 0.650 | ROC: 0.626: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 49. Validation. Loss: 0.632 | ROC: 0.550: 100%|██████████| 5/5 [00:01<00:00,  3.80it/s]
# Epoch: 50. Train. Loss: 0.659 | ROC: 0.584: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 50. Validation. Loss: 0.636 | ROC: 0.553: 100%|██████████| 5/5 [00:01<00:00,  3.86it/s]
# Best ROC-AUC in fold 1 was 0.7490
# Final ROC-AUC in fold 1 was 0.6230
# Best model name in fold 1 was eca_nfnet_l0_35_epoch_0.749_roc_auc.pth
# Finishing last run (ID:2toedihs) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Train ROC</td><td>▅▇▆▆▄▇▃▅▅▄▄▅█▄▁▇▅▅▆▅█▄▄▆▇▄▆▄▄▆▇▅▇▂▆▅▂▇▇▅</td></tr><tr><td>Train loss</td><td>▅▄▅▄▆▄▇▆▅▆▅▄▄▅█▄▅▂▃▇▄▅▅▇▄▂▃▂▇▂▃▇▅▁▂▄█▂▃█</td></tr><tr><td>Valid Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Valid ROC</td><td>▁▇▁▁▁▁▁▁▁▆▁▁▇▁▁▁▁▁▁▁█▁▁█▁▁▁▁▁▁▁█▁▁█▁▁▁▁▆</td></tr><tr><td>Valid loss</td><td>▅▃▄▆▅▆▂▅▂▄▆▃▃▄▅▅▄▄▅▃▂▂▄▄▆▂▃▄▂▅▇▁▅▁▁▆▂▅█▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>50</td></tr><tr><td>Train ROC</td><td>0.43333</td></tr><tr><td>Train loss</td><td>0.61256</td></tr><tr><td>Valid Epoch</td><td>50</td></tr><tr><td>Valid ROC</td><td>0.5</td></tr><tr><td>Valid loss</td><td>0.54457</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">22-08-03 23_05_43 - fold 1</strong>: <a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/2toedihs" target="_blank">https://wandb.ai/mllm/eca-NFNet-Mixup/runs/2toedihs</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220803_230543-2toedihs\logs</code>
# Successfully finished last run (ID:2toedihs). Initializing new run:<br/>
# wandb version 0.13.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>D:\UoL\Level 6\CM3070 - Final Project\SETI Signal Detection\Prototype\wandb\run-20220803_234556-wi67c32o</code>
# Syncing run <strong><a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/wi67c32o" target="_blank">22-08-03 23_45_56 - fold 2</a></strong> to <a href="https://wandb.ai/mllm/eca-NFNet-Mixup" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ======================================== Fold: 2 ========================================
# Epoch: 1. Train. Loss: 0.651 | ROC: 0.608: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 1. Validation. Loss: 0.539 | ROC: 0.586: 100%|██████████| 5/5 [00:01<00:00,  3.92it/s]
# Epoch: 2. Train. Loss: 0.655 | ROC: 0.579: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 2. Validation. Loss: 0.528 | ROC: 0.554: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 3. Train. Loss: 0.664 | ROC: 0.575: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 3. Validation. Loss: 0.499 | ROC: 0.567: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 4. Train. Loss: 0.652 | ROC: 0.597: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 4. Validation. Loss: 0.511 | ROC: 0.575: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 5. Train. Loss: 0.643 | ROC: 0.610: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 5. Validation. Loss: 0.480 | ROC: 0.582: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 6. Train. Loss: 0.638 | ROC: 0.623: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 6. Validation. Loss: 0.500 | ROC: 0.568: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 7. Train. Loss: 0.646 | ROC: 0.597: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 7. Validation. Loss: 0.489 | ROC: 0.576: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 8. Train. Loss: 0.635 | ROC: 0.639: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 8. Validation. Loss: 0.477 | ROC: 0.578: 100%|██████████| 5/5 [00:01<00:00,  3.80it/s]
# Epoch: 9. Train. Loss: 0.634 | ROC: 0.612: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 9. Validation. Loss: 0.476 | ROC: 0.578: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 10. Train. Loss: 0.625 | ROC: 0.676: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 10. Validation. Loss: 0.473 | ROC: 0.577: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 11. Train. Loss: 0.629 | ROC: 0.645: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 11. Validation. Loss: 0.473 | ROC: 0.576: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 12. Train. Loss: 0.631 | ROC: 0.652: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 12. Validation. Loss: 0.473 | ROC: 0.575: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 13. Train. Loss: 0.627 | ROC: 0.654: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 13. Validation. Loss: 0.461 | ROC: 0.579: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 14. Train. Loss: 0.624 | ROC: 0.694: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 14. Validation. Loss: 0.458 | ROC: 0.575: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 15. Train. Loss: 0.626 | ROC: 0.647: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 15. Validation. Loss: 0.474 | ROC: 0.567: 100%|██████████| 5/5 [00:01<00:00,  3.91it/s]
# Epoch: 16. Train. Loss: 0.609 | ROC: 0.676: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 16. Validation. Loss: 0.499 | ROC: 0.575: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 17. Train. Loss: 0.639 | ROC: 0.630: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 17. Validation. Loss: 0.494 | ROC: 0.550: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 18. Train. Loss: 0.637 | ROC: 0.652: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 18. Validation. Loss: 0.499 | ROC: 0.571: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 19. Train. Loss: 0.631 | ROC: 0.662: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 19. Validation. Loss: 0.470 | ROC: 0.583: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 20. Train. Loss: 0.631 | ROC: 0.673: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 20. Validation. Loss: 0.494 | ROC: 0.583: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 21. Train. Loss: 0.629 | ROC: 0.631: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 21. Validation. Loss: 0.483 | ROC: 0.570: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 22. Train. Loss: 0.627 | ROC: 0.651: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 22. Validation. Loss: 0.512 | ROC: 0.542: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 23. Train. Loss: 0.627 | ROC: 0.627: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 23. Validation. Loss: 0.499 | ROC: 0.560: 100%|██████████| 5/5 [00:01<00:00,  3.86it/s]
# Epoch: 24. Train. Loss: 0.643 | ROC: 0.624: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 24. Validation. Loss: 0.497 | ROC: 0.554: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 25. Train. Loss: 0.616 | ROC: 0.645: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 25. Validation. Loss: 0.521 | ROC: 0.544: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 26. Train. Loss: 0.622 | ROC: 0.643: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 26. Validation. Loss: 0.481 | ROC: 0.574: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 27. Train. Loss: 0.604 | ROC: 0.656: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 27. Validation. Loss: 0.504 | ROC: 0.559: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 28. Train. Loss: 0.609 | ROC: 0.681: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 28. Validation. Loss: 0.485 | ROC: 0.569: 100%|██████████| 5/5 [00:01<00:00,  3.56it/s]
# Epoch: 29. Train. Loss: 0.624 | ROC: 0.657: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 29. Validation. Loss: 0.476 | ROC: 0.569: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 30. Train. Loss: 0.596 | ROC: 0.661: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 30. Validation. Loss: 0.476 | ROC: 0.567: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 31. Train. Loss: 0.606 | ROC: 0.636: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 31. Validation. Loss: 0.475 | ROC: 0.567: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 32. Train. Loss: 0.612 | ROC: 0.662: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 32. Validation. Loss: 0.475 | ROC: 0.567: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 33. Train. Loss: 0.591 | ROC: 0.621: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 33. Validation. Loss: 0.474 | ROC: 0.562: 100%|██████████| 5/5 [00:01<00:00,  3.81it/s]
# Epoch: 34. Train. Loss: 0.602 | ROC: 0.612: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 34. Validation. Loss: 0.488 | ROC: 0.555: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 35. Train. Loss: 0.616 | ROC: 0.675: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 35. Validation. Loss: 0.477 | ROC: 0.558: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 36. Train. Loss: 0.598 | ROC: 0.686: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 36. Validation. Loss: 0.517 | ROC: 0.555: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 37. Train. Loss: 0.620 | ROC: 0.652: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 37. Validation. Loss: 0.469 | ROC: 0.571: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 38. Train. Loss: 0.612 | ROC: 0.681: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 38. Validation. Loss: 0.525 | ROC: 0.537: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 39. Train. Loss: 0.598 | ROC: 0.650: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 39. Validation. Loss: 0.490 | ROC: 0.554: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 40. Train. Loss: 0.605 | ROC: 0.642: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 40. Validation. Loss: 0.579 | ROC: 0.528: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 41. Train. Loss: 0.624 | ROC: 0.671: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 41. Validation. Loss: 0.511 | ROC: 0.582: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 42. Train. Loss: 0.600 | ROC: 0.668: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 42. Validation. Loss: 0.460 | ROC: 0.560: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 43. Train. Loss: 0.622 | ROC: 0.652: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 43. Validation. Loss: 0.495 | ROC: 0.547: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 44. Train. Loss: 0.605 | ROC: 0.645: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 44. Validation. Loss: 0.505 | ROC: 0.543: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 45. Train. Loss: 0.597 | ROC: 0.647: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 45. Validation. Loss: 0.539 | ROC: 0.546: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 46. Train. Loss: 0.595 | ROC: 0.646: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 46. Validation. Loss: 0.517 | ROC: 0.546: 100%|██████████| 5/5 [00:01<00:00,  3.81it/s]
# Epoch: 47. Train. Loss: 0.600 | ROC: 0.640: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 47. Validation. Loss: 0.530 | ROC: 0.557: 100%|██████████| 5/5 [00:01<00:00,  3.86it/s]
# Epoch: 48. Train. Loss: 0.605 | ROC: 0.659: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 48. Validation. Loss: 0.532 | ROC: 0.539: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 49. Train. Loss: 0.580 | ROC: 0.644: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 49. Validation. Loss: 0.528 | ROC: 0.545: 100%|██████████| 5/5 [00:01<00:00,  3.80it/s]
# Epoch: 50. Train. Loss: 0.603 | ROC: 0.699: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 50. Validation. Loss: 0.524 | ROC: 0.546: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Best ROC-AUC in fold 2 was 0.8600
# Final ROC-AUC in fold 2 was 0.7930
# Best model name in fold 2 was eca_nfnet_l0_3_epoch_0.86_roc_auc.pth
# Finishing last run (ID:wi67c32o) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Train ROC</td><td>▅▆▆▂▂▃█▆▅▄▅▇▆▅▆▃▇▅▃▅▃▄▅▆▇▇▄▆▄▆▆▄▄▄▃▁█▂▂▂</td></tr><tr><td>Train loss</td><td>▅▅▄▆█▅▃▅▅▄▅▃▆▆▇▅▅▅▇▇█▇▇▄▂▃▇▅▅▆▄▇▆▆▂▂▁▃▆▆</td></tr><tr><td>Valid Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Valid ROC</td><td>▁▆▁▁▁▁▁▁▁█▁▁█▁▁▁▁▁▁▁█▁▁▇▁▁▁▁▁▁▁▄▁▁▅▁▁▁▁▅</td></tr><tr><td>Valid loss</td><td>▇▄▄▄▅▆▃▄▅▅▄▃▄▃▄▄▆▃▅█▄▄▂▅▄▂▅▇▄▅▆█▆▁▆▇▂▆█▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>50</td></tr><tr><td>Train ROC</td><td>0.81667</td></tr><tr><td>Train loss</td><td>0.64481</td></tr><tr><td>Valid Epoch</td><td>50</td></tr><tr><td>Valid ROC</td><td>0.5</td></tr><tr><td>Valid loss</td><td>0.29554</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">22-08-03 23_45_56 - fold 2</strong>: <a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/wi67c32o" target="_blank">https://wandb.ai/mllm/eca-NFNet-Mixup/runs/wi67c32o</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220803_234556-wi67c32o\logs</code>
# Successfully finished last run (ID:wi67c32o). Initializing new run:<br/>
# wandb version 0.13.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>D:\UoL\Level 6\CM3070 - Final Project\SETI Signal Detection\Prototype\wandb\run-20220804_002612-2za4awwr</code>
# Syncing run <strong><a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/2za4awwr" target="_blank">22-08-04 00_26_12 - fold 3</a></strong> to <a href="https://wandb.ai/mllm/eca-NFNet-Mixup" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ======================================== Fold: 3 ========================================
# Epoch: 1. Train. Loss: 0.594 | ROC: 0.648: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 1. Validation. Loss: 0.323 | ROC: 0.587: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 2. Train. Loss: 0.612 | ROC: 0.698: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 2. Validation. Loss: 0.323 | ROC: 0.585: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 3. Train. Loss: 0.583 | ROC: 0.659: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 3. Validation. Loss: 0.325 | ROC: 0.586: 100%|██████████| 5/5 [00:01<00:00,  3.75it/s]
# Epoch: 4. Train. Loss: 0.590 | ROC: 0.655: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 4. Validation. Loss: 0.324 | ROC: 0.577: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 5. Train. Loss: 0.586 | ROC: 0.714: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 5. Validation. Loss: 0.331 | ROC: 0.571: 100%|██████████| 5/5 [00:01<00:00,  3.75it/s]
# Epoch: 6. Train. Loss: 0.579 | ROC: 0.682: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 6. Validation. Loss: 0.332 | ROC: 0.579: 100%|██████████| 5/5 [00:01<00:00,  3.78it/s]
# Epoch: 7. Train. Loss: 0.584 | ROC: 0.660: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 7. Validation. Loss: 0.389 | ROC: 0.568: 100%|██████████| 5/5 [00:01<00:00,  3.80it/s]
# Epoch: 8. Train. Loss: 0.596 | ROC: 0.673: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 8. Validation. Loss: 0.419 | ROC: 0.567: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 9. Train. Loss: 0.599 | ROC: 0.625: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 9. Validation. Loss: 0.427 | ROC: 0.551: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 10. Train. Loss: 0.604 | ROC: 0.632: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 10. Validation. Loss: 0.419 | ROC: 0.560: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 11. Train. Loss: 0.603 | ROC: 0.660: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 11. Validation. Loss: 0.440 | ROC: 0.582: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 12. Train. Loss: 0.607 | ROC: 0.641: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 12. Validation. Loss: 0.451 | ROC: 0.554: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 13. Train. Loss: 0.597 | ROC: 0.644: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 13. Validation. Loss: 0.455 | ROC: 0.542: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 14. Train. Loss: 0.603 | ROC: 0.690: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 14. Validation. Loss: 0.429 | ROC: 0.567: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 15. Train. Loss: 0.602 | ROC: 0.685: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 15. Validation. Loss: 0.485 | ROC: 0.550: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 16. Train. Loss: 0.598 | ROC: 0.660: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 16. Validation. Loss: 0.419 | ROC: 0.550: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 17. Train. Loss: 0.590 | ROC: 0.707: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 17. Validation. Loss: 0.455 | ROC: 0.549: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 18. Train. Loss: 0.580 | ROC: 0.691: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 18. Validation. Loss: 0.422 | ROC: 0.566: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 19. Train. Loss: 0.579 | ROC: 0.724: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 19. Validation. Loss: 0.427 | ROC: 0.563: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 20. Train. Loss: 0.572 | ROC: 0.670: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 20. Validation. Loss: 0.427 | ROC: 0.563: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 21. Train. Loss: 0.557 | ROC: 0.633: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 21. Validation. Loss: 0.426 | ROC: 0.563: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 22. Train. Loss: 0.569 | ROC: 0.647: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 22. Validation. Loss: 0.417 | ROC: 0.562: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 23. Train. Loss: 0.580 | ROC: 0.691: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 23. Validation. Loss: 0.422 | ROC: 0.563: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 24. Train. Loss: 0.562 | ROC: 0.698: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 24. Validation. Loss: 0.445 | ROC: 0.551: 100%|██████████| 5/5 [00:01<00:00,  3.95it/s]
# Epoch: 25. Train. Loss: 0.582 | ROC: 0.684: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 25. Validation. Loss: 0.398 | ROC: 0.555: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 26. Train. Loss: 0.565 | ROC: 0.724: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 26. Validation. Loss: 0.446 | ROC: 0.538: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 27. Train. Loss: 0.597 | ROC: 0.645: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 27. Validation. Loss: 0.471 | ROC: 0.543: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 28. Train. Loss: 0.575 | ROC: 0.665: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 28. Validation. Loss: 0.460 | ROC: 0.538: 100%|██████████| 5/5 [00:01<00:00,  3.76it/s]
# Epoch: 29. Train. Loss: 0.589 | ROC: 0.651: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 29. Validation. Loss: 0.454 | ROC: 0.546: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 30. Train. Loss: 0.571 | ROC: 0.709: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 30. Validation. Loss: 0.439 | ROC: 0.558: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 31. Train. Loss: 0.574 | ROC: 0.713: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 31. Validation. Loss: 0.463 | ROC: 0.544: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 32. Train. Loss: 0.576 | ROC: 0.699: 100%|██████████| 40/40 [00:47<00:00,  1.18s/it]
# Epoch: 32. Validation. Loss: 0.439 | ROC: 0.554: 100%|██████████| 5/5 [00:01<00:00,  3.53it/s]
# Epoch: 33. Train. Loss: 0.594 | ROC: 0.674: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 33. Validation. Loss: 0.480 | ROC: 0.550: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 34. Train. Loss: 0.581 | ROC: 0.678: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 34. Validation. Loss: 0.503 | ROC: 0.544: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 35. Train. Loss: 0.576 | ROC: 0.736: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 35. Validation. Loss: 0.505 | ROC: 0.534: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 36. Train. Loss: 0.572 | ROC: 0.660: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 36. Validation. Loss: 0.472 | ROC: 0.553: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 37. Train. Loss: 0.558 | ROC: 0.683: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 37. Validation. Loss: 0.457 | ROC: 0.554: 100%|██████████| 5/5 [00:01<00:00,  3.80it/s]
# Epoch: 38. Train. Loss: 0.555 | ROC: 0.721: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 38. Validation. Loss: 0.471 | ROC: 0.561: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 39. Train. Loss: 0.565 | ROC: 0.680: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 39. Validation. Loss: 0.476 | ROC: 0.558: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 40. Train. Loss: 0.556 | ROC: 0.707: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 40. Validation. Loss: 0.468 | ROC: 0.558: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 41. Train. Loss: 0.532 | ROC: 0.690: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 41. Validation. Loss: 0.465 | ROC: 0.559: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 42. Train. Loss: 0.552 | ROC: 0.672: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 42. Validation. Loss: 0.458 | ROC: 0.558: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 43. Train. Loss: 0.565 | ROC: 0.649: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 43. Validation. Loss: 0.450 | ROC: 0.558: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 44. Train. Loss: 0.564 | ROC: 0.659: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 44. Validation. Loss: 0.432 | ROC: 0.559: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 45. Train. Loss: 0.528 | ROC: 0.730: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 45. Validation. Loss: 0.444 | ROC: 0.568: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 46. Train. Loss: 0.536 | ROC: 0.694: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 46. Validation. Loss: 0.415 | ROC: 0.562: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 47. Train. Loss: 0.534 | ROC: 0.705: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 47. Validation. Loss: 0.483 | ROC: 0.536: 100%|██████████| 5/5 [00:01<00:00,  3.80it/s]
# Epoch: 48. Train. Loss: 0.561 | ROC: 0.649: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 48. Validation. Loss: 0.451 | ROC: 0.553: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 49. Train. Loss: 0.571 | ROC: 0.649: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 49. Validation. Loss: 0.437 | ROC: 0.575: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 50. Train. Loss: 0.552 | ROC: 0.720: 100%|██████████| 40/40 [00:46<00:00,  1.17s/it]
# Epoch: 50. Validation. Loss: 0.459 | ROC: 0.546: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Best ROC-AUC in fold 3 was 0.9610
# Final ROC-AUC in fold 3 was 0.8580
# Best model name in fold 3 was eca_nfnet_l0_1_epoch_0.961_roc_auc.pth
# Finishing last run (ID:2za4awwr) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
# Epoch: 31. Train. Loss: 0.489 | ROC: 0.738: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 31. Validation. Loss: 0.105 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 32. Train. Loss: 0.477 | ROC: 0.726: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 32. Validation. Loss: 0.111 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 33. Train. Loss: 0.456 | ROC: 0.676: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 33. Validation. Loss: 0.107 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 34. Train. Loss: 0.459 | ROC: 0.702: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 34. Validation. Loss: 0.113 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 35. Train. Loss: 0.491 | ROC: 0.747: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 35. Validation. Loss: 0.120 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 36. Train. Loss: 0.457 | ROC: 0.763: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 36. Validation. Loss: 0.097 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 37. Train. Loss: 0.461 | ROC: 0.715: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 37. Validation. Loss: 0.102 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 38. Train. Loss: 0.471 | ROC: 0.730: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 38. Validation. Loss: 0.109 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 39. Train. Loss: 0.475 | ROC: 0.711: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 39. Validation. Loss: 0.132 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 40. Train. Loss: 0.494 | ROC: 0.723: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 40. Validation. Loss: 0.113 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 41. Train. Loss: 0.491 | ROC: 0.744: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 41. Validation. Loss: 0.159 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 42. Train. Loss: 0.461 | ROC: 0.708: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 42. Validation. Loss: 0.156 | ROC: 0.599: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 43. Train. Loss: 0.461 | ROC: 0.803: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 43. Validation. Loss: 0.158 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 44. Train. Loss: 0.482 | ROC: 0.743: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 44. Validation. Loss: 0.108 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 45. Train. Loss: 0.442 | ROC: 0.799: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 45. Validation. Loss: 0.092 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 46. Train. Loss: 0.477 | ROC: 0.732: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 46. Validation. Loss: 0.120 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 47. Train. Loss: 0.464 | ROC: 0.749: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 47. Validation. Loss: 0.127 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 48. Train. Loss: 0.412 | ROC: 0.803: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 48. Validation. Loss: 0.111 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 49. Train. Loss: 0.438 | ROC: 0.725: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 49. Validation. Loss: 0.105 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 50. Train. Loss: 0.451 | ROC: 0.796: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 50. Validation. Loss: 0.105 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Best ROC-AUC in fold 8 was 1.0000
# Final ROC-AUC in fold 8 was 0.9980
# Best model name in fold 8 was eca_nfnet_l0_30_epoch_1.0_roc_auc.pth
# Finishing last run (ID:3ehnffdn) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Train ROC</td><td>▆▇▄▄██▃▃▂▇▆▃▇▄█▇▇█▇▂▇█▁▃▃▅▃▄▇▆▆▇█▂▄▅▄█▄▃</td></tr><tr><td>Train loss</td><td>▆▅▄█▄▅▆▄▄▇▆▁▆▂▃▃▆▂▆▅▅▃█▂▇▅▇▂▄▆▆▆▅▂▆▆▆▃▆▆</td></tr><tr><td>Valid Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Valid ROC</td><td>▁█▁▁▁▁▁▁▁█▁▁█▁▁▁▁▁▁▁█▁▁█▁▁▁▁▁▁▁█▁▁█▁▁▁▁█</td></tr><tr><td>Valid loss</td><td>▂▄▃▃▁▂▂▁▂▂▂▂▂▃▂▁▄▃▂▁▅█▂▃█▂▁▂▂▂▄▃█▂▄▂▂▂▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train Epoch</td><td>50</td></tr><tr><td>Train ROC</td><td>0.87879</td></tr><tr><td>Train loss</td><td>0.53908</td></tr><tr><td>Valid Epoch</td><td>50</td></tr><tr><td>Valid ROC</td><td>0.5</td></tr><tr><td>Valid loss</td><td>0.09158</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">22-08-04 03_46_35 - fold 8</strong>: <a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/3ehnffdn" target="_blank">https://wandb.ai/mllm/eca-NFNet-Mixup/runs/3ehnffdn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220804_034635-3ehnffdn\logs</code>
# Successfully finished last run (ID:3ehnffdn). Initializing new run:<br/>
# wandb version 0.13.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>D:\UoL\Level 6\CM3070 - Final Project\SETI Signal Detection\Prototype\wandb\run-20220804_042609-38q54uzb</code>
# Syncing run <strong><a href="https://wandb.ai/mllm/eca-NFNet-Mixup/runs/38q54uzb" target="_blank">22-08-04 04_26_09 - fold 9</a></strong> to <a href="https://wandb.ai/mllm/eca-NFNet-Mixup" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ======================================== Fold: 9 ========================================
# Epoch: 1. Train. Loss: 0.414 | ROC: 0.781: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 1. Validation. Loss: 0.054 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.99it/s]
# Epoch: 2. Train. Loss: 0.402 | ROC: 0.796: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# Epoch: 2. Validation. Loss: 0.052 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.99it/s]
# Epoch: 3. Train. Loss: 0.443 | ROC: 0.759: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# Epoch: 3. Validation. Loss: 0.055 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 4. Train. Loss: 0.410 | ROC: 0.653: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# Epoch: 4. Validation. Loss: 0.051 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 5. Train. Loss: 0.421 | ROC: 0.695: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 5. Validation. Loss: 0.045 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 6. Train. Loss: 0.457 | ROC: 0.736: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 6. Validation. Loss: 0.060 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 7. Train. Loss: 0.494 | ROC: 0.768: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 7. Validation. Loss: 0.092 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 8. Train. Loss: 0.459 | ROC: 0.737: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# Epoch: 8. Validation. Loss: 0.046 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 9. Train. Loss: 0.487 | ROC: 0.766: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 9. Validation. Loss: 0.076 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 10. Train. Loss: 0.451 | ROC: 0.727: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 10. Validation. Loss: 0.152 | ROC: 0.595: 100%|██████████| 5/5 [00:01<00:00,  3.95it/s]
# Epoch: 11. Train. Loss: 0.446 | ROC: 0.759: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 11. Validation. Loss: 0.091 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 12. Train. Loss: 0.443 | ROC: 0.719: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 12. Validation. Loss: 0.061 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 13. Train. Loss: 0.419 | ROC: 0.767: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 13. Validation. Loss: 0.067 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 14. Train. Loss: 0.452 | ROC: 0.670: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# Epoch: 14. Validation. Loss: 0.081 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 15. Train. Loss: 0.437 | ROC: 0.707: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# Epoch: 15. Validation. Loss: 0.081 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.99it/s]
# Epoch: 16. Train. Loss: 0.425 | ROC: 0.770: 100%|██████████| 40/40 [00:45<00:00,  1.13s/it]
# Epoch: 16. Validation. Loss: 0.081 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 17. Train. Loss: 0.411 | ROC: 0.662: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 17. Validation. Loss: 0.058 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 18. Train. Loss: 0.445 | ROC: 0.765: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 18. Validation. Loss: 0.064 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 19. Train. Loss: 0.424 | ROC: 0.750: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 19. Validation. Loss: 0.065 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.70it/s]
# Epoch: 20. Train. Loss: 0.442 | ROC: 0.723: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 20. Validation. Loss: 0.065 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 21. Train. Loss: 0.443 | ROC: 0.722: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 21. Validation. Loss: 0.065 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 22. Train. Loss: 0.478 | ROC: 0.765: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 22. Validation. Loss: 0.064 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# Epoch: 23. Train. Loss: 0.423 | ROC: 0.771: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 23. Validation. Loss: 0.058 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.86it/s]
# Epoch: 24. Train. Loss: 0.441 | ROC: 0.751: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 24. Validation. Loss: 0.060 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 25. Train. Loss: 0.450 | ROC: 0.748: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 25. Validation. Loss: 0.081 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 26. Train. Loss: 0.423 | ROC: 0.693: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 26. Validation. Loss: 0.083 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Epoch: 27. Train. Loss: 0.461 | ROC: 0.751: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 27. Validation. Loss: 0.092 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# Epoch: 28. Train. Loss: 0.442 | ROC: 0.766: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 28. Validation. Loss: 0.106 | ROC: 0.597: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 29. Train. Loss: 0.442 | ROC: 0.776: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 29. Validation. Loss: 0.115 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.91it/s]
# Epoch: 30. Train. Loss: 0.433 | ROC: 0.765: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 30. Validation. Loss: 0.090 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 31. Train. Loss: 0.480 | ROC: 0.770: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 31. Validation. Loss: 0.134 | ROC: 0.592: 100%|██████████| 5/5 [00:01<00:00,  3.86it/s]
# Epoch: 32. Train. Loss: 0.490 | ROC: 0.717: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 32. Validation. Loss: 0.130 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 33. Train. Loss: 0.436 | ROC: 0.746: 100%|██████████| 40/40 [00:45<00:00,  1.14s/it]
# Epoch: 33. Validation. Loss: 0.123 | ROC: 0.597: 100%|██████████| 5/5 [00:01<00:00,  3.94it/s]
# Epoch: 34. Train. Loss: 0.456 | ROC: 0.789: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 34. Validation. Loss: 0.104 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 35. Train. Loss: 0.460 | ROC: 0.739: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 35. Validation. Loss: 0.086 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 36. Train. Loss: 0.487 | ROC: 0.721: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 36. Validation. Loss: 0.085 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 37. Train. Loss: 0.419 | ROC: 0.707: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 37. Validation. Loss: 0.071 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 38. Train. Loss: 0.416 | ROC: 0.738: 100%|██████████| 40/40 [00:45<00:00,  1.15s/it]
# Epoch: 38. Validation. Loss: 0.068 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.90it/s]
# Epoch: 39. Train. Loss: 0.497 | ROC: 0.690: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 39. Validation. Loss: 0.076 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.82it/s]
# Epoch: 40. Train. Loss: 0.422 | ROC: 0.778: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 40. Validation. Loss: 0.073 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# Epoch: 41. Train. Loss: 0.462 | ROC: 0.767: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 41. Validation. Loss: 0.073 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 42. Train. Loss: 0.415 | ROC: 0.764: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 42. Validation. Loss: 0.071 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.93it/s]
# Epoch: 43. Train. Loss: 0.406 | ROC: 0.734: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 43. Validation. Loss: 0.071 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 44. Train. Loss: 0.466 | ROC: 0.765: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 44. Validation. Loss: 0.069 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 45. Train. Loss: 0.428 | ROC: 0.788: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 45. Validation. Loss: 0.066 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Epoch: 46. Train. Loss: 0.450 | ROC: 0.681: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 46. Validation. Loss: 0.102 | ROC: 0.598: 100%|██████████| 5/5 [00:01<00:00,  3.92it/s]
# Epoch: 47. Train. Loss: 0.453 | ROC: 0.759: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 47. Validation. Loss: 0.093 | ROC: 0.600: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 48. Train. Loss: 0.448 | ROC: 0.720: 100%|██████████| 40/40 [00:46<00:00,  1.16s/it]
# Epoch: 48. Validation. Loss: 0.107 | ROC: 0.598: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# Epoch: 49. Train. Loss: 0.424 | ROC: 0.818: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 49. Validation. Loss: 0.113 | ROC: 0.595: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Epoch: 50. Train. Loss: 0.455 | ROC: 0.757: 100%|██████████| 40/40 [00:46<00:00,  1.15s/it]
# Epoch: 50. Validation. Loss: 0.212 | ROC: 0.592: 100%|██████████| 5/5 [00:01<00:00,  3.88it/s]
# Best ROC-AUC in fold 9 was 1.0000
# Final ROC-AUC in fold 9 was 0.9840
# Best model name in fold 9 was eca_nfnet_l0_30_epoch_1.0_roc_auc.pth

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Run best performing model against test set

# %%
def get_test_loader(test_data):
    test_set = CustomDataset(
        images_filepaths=test_data['image_filepath'].values,
        targets=test_df['target'].values,
        # transform=get_valid_transforms()
    )

    return DataLoader(
        test_set,
        batch_size=config['batch_size'],
        shuffle=False,
        # num_workers=config['num_workers'],
        pin_memory=True
    )

    return test_loader

# %%
def test_model(model_path):
    final_targets = []
    final_outputs = []

    model = EcaNFNet()
    model.load_state_dict(torch.load(model_path))
    model.eval()

    metric_monitor = MetricMonitor()
    test_loader = get_test_loader(test_df)
    stream = tqdm(enumerate(test_loader), total=len(test_loader))

    with torch.no_grad():
        for i, (images, target) in stream:
            images = images.to('cpu', non_blocking=True)
            target = target.to('cpu', non_blocking=True).float().view(-1, 1)

            output = model(images)
            loss = criterion(output, target)
            roc_score = use_roc_score(output, target)

            metric_monitor.update('Loss', loss.item())
            metric_monitor.update('ROC', roc_score)

            wandb.log({'Test loss': loss.item(), ' Test ROC': roc_score})

            stream.set_description('Test. {metric_monitor}'.format(metric_monitor=metric_monitor))

            targets = target.detach().cpu().numpy().tolist()
            outputs = output.detach().cpu().numpy().tolist()

            final_targets.extend(targets)
            final_outputs.extend(outputs)

    return final_outputs, final_targets

# %%
test_outputs = []
test_targets = []

test_outputs, test_targets = test_model(os.path.join(models_dir, 'eca_nfnet_l0_30_epoch_1.0_roc_auc.pth'))
# Out:
# Test. Loss: 0.439 | ROC: 0.514: 100%|██████████| 20/20 [03:00<00:00,  9.03s/it]

# %%
test_df = pd.DataFrame([test_targets, test_outputs])
test_df = test_df.transpose()
test_df.columns = ['label', 'prediction']

test_df['label'] = test_df['label'].apply(lambda x: x[0])
test_df['prediction'] = test_df['prediction'].apply(lambda x: x[0])

# Use threshold of > 0.5 for a positive prediction, else it is a negative prediction
test_df['prediction'] = test_df['prediction'].apply(lambda x: 1.0 if x > 0.5 else 0)

# %%
pd.crosstab(test_df['prediction'], test_df['label'])
# Out:
# label       0.0  1.0
# prediction
# 0.0         280   65
# 1.0          33  231
